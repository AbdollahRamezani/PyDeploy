# %%
import requests

# %%
url = "https://my-api.plantnet.org/v2/identify/all"

headers = {
}

payload = {
   "api-key": "2b104UygdfHGVTT6aDtFn3baQ"
}

files = {
    "images":open("/content/shamadora.jpg", "rb")
}

response = requests.post(url, headers=headers, params=payload, files=files)

response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'query': {'project': 'all',
#   'images': ['e5e6c7f4285f519b5c6e7d9013282774'],
#   'organs': ['auto'],
#   'includeRelatedImages': False,
#   'noReject': False},
#  'language': 'en',
#  'preferedReferential': 'k-world-flora',
#  'bestMatch': 'Chamaedorea elegans Mart.',
#  'results': [{'score': 0.50035,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea elegans',
#     'scientificNameAuthorship': 'Mart.',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Parlor palm', 'Parlour palm', 'Good-luck palm'],
#     'scientificName': 'Chamaedorea elegans Mart.'},
#    'gbif': {'id': '2734661'},
#    'powo': {'id': '54865-2'}},
#   {'score': 0.17327,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea elatior',
#     'scientificNameAuthorship': 'Mart.',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': [],
#     'scientificName': 'Chamaedorea elatior Mart.'},
#    'gbif': {'id': '2734637'},
#    'powo': {'id': '54864-2'},
#    'iucn': {'id': '55950006', 'category': 'LC'}},
#   {'score': 0.10566,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea seifrizii',
#     'scientificNameAuthorship': 'Burret',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Bamboo palm', 'Parlor palm', 'Reed palm'],
#     'scientificName': 'Chamaedorea seifrizii Burret'},
#    'gbif': {'id': '2734708'},
#    'powo': {'id': '54954-2'},
#    'iucn': {'id': '58410095', 'category': 'LC'}},
#   {'score': 0.03946,
#    'species': {'scientificNameWithoutAuthor': 'Howea forsteriana',
#     'scientificNameAuthorship': '(F.Muell.) Becc.',
#     'genus': {'scientificNameWithoutAuthor': 'Howea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Howea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Kentia palm', 'Sentrypalm', 'Thatch palm'],
#     'scientificName': 'Howea forsteriana (F.Muell.) Becc.'},
#    'gbif': {'id': '7857942'},
#    'powo': {'id': '667434-1'},
#    'iucn': {'id': '38577', 'category': 'VU'}},
#   {'score': 0.00635,
#    'species': {'scientificNameWithoutAuthor': 'Elaeis guineensis',
#     'scientificNameAuthorship': 'Jacq.',
#     'genus': {'scientificNameWithoutAuthor': 'Elaeis',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Elaeis'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['African oil palm', 'Oil palm', 'Macaw-fat'],
#     'scientificName': 'Elaeis guineensis Jacq.'},
#    'gbif': {'id': '2731882'},
#    'powo': {'id': '666802-1'},
#    'iucn': {'id': '13416970', 'category': 'LC'}},
#   {'score': 0.00274,
#    'species': {'scientificNameWithoutAuthor': 'Salacca zalacca',
#     'scientificNameAuthorship': '(Gaertn.) Voss',
#     'genus': {'scientificNameWithoutAuthor': 'Salacca',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Salacca'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Salak', 'Salak palm', 'Snakefruit'],
#     'scientificName': 'Salacca zalacca (Gaertn.) Voss'},
#    'gbif': {'id': '2731764'},
#    'powo': {'id': '670335-1'}},
#   {'score': 0.00259,
#    'species': {'scientificNameWithoutAuthor': 'Oxalis lasiopetala',
#     'scientificNameAuthorship': 'Zucc.',
#     'genus': {'scientificNameWithoutAuthor': 'Oxalis',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Oxalis'},
#     'family': {'scientificNameWithoutAuthor': 'Oxalidaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Oxalidaceae'},
#     'commonNames': [],
#     'scientificName': 'Oxalis lasiopetala Zucc.'},
#    'gbif': {'id': '7318248'},
#    'powo': {'id': '375048-1'}},
#   {'score': 0.00258,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea hooperiana',
#     'scientificNameAuthorship': 'Hodel',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': [],
#     'scientificName': 'Chamaedorea hooperiana Hodel'},
#    'gbif': {'id': '2734527'},
#    'powo': {'id': '304309-2'}},
#   {'score': 0.00243,
#    'species': {'scientificNameWithoutAuthor': 'Ratibida pinnata',
#     'scientificNameAuthorship': '(Vent.) Barnhart',
#     'genus': {'scientificNameWithoutAuthor': 'Ratibida',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Ratibida'},
#     'family': {'scientificNameWithoutAuthor': 'Asteraceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asteraceae'},
#     'commonNames': ['Pinnate prairie coneflower',
#      'Drooping prairie-coneflower',
#      'Gray-head prairie-coneflower'],
#     'scientificName': 'Ratibida pinnata (Vent.) Barnhart'},
#    'gbif': {'id': '3087184'},
#    'powo': {'id': '217881-2'}},
#   {'score': 0.00242,
#    'species': {'scientificNameWithoutAuthor': 'Dypsis lutescens',
#     'scientificNameAuthorship': '(H.Wendl.) Beentje & J.Dransf.',
#     'genus': {'scientificNameWithoutAuthor': 'Dypsis',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dypsis'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Areca palm', 'Yellow butterfly palm', 'Butterfly palm'],
#     'scientificName': 'Dypsis lutescens (H.Wendl.) Beentje & J.Dransf.'},
#    'gbif': {'id': '2735935'},
#    'powo': {'id': '985360-1'},
#    'iucn': {'id': '195960', 'category': 'NT'}},
#   {'score': 0.00236,
#    'species': {'scientificNameWithoutAuthor': 'Dracaena surculosa',
#     'scientificNameAuthorship': 'Lindl.',
#     'genus': {'scientificNameWithoutAuthor': 'Dracaena',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Dracaena'},
#     'family': {'scientificNameWithoutAuthor': 'Asparagaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Asparagaceae'},
#     'commonNames': ['Gold dust dracaena', 'Spotted dracaena', 'Bambu jepang'],
#     'scientificName': 'Dracaena surculosa Lindl.'},
#    'gbif': {'id': '5304547'},
#    'powo': {'id': '534384-1'}},
#   {'score': 0.00236,
#    'species': {'scientificNameWithoutAuthor': 'Saribus rotundifolius',
#     'scientificNameAuthorship': '(Lam.) Blume',
#     'genus': {'scientificNameWithoutAuthor': 'Saribus',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Saribus'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Round-leaf fountain palm', 'Palm'],
#     'scientificName': 'Saribus rotundifolius (Lam.) Blume'},
#    'gbif': {'id': '2733431'},
#    'powo': {'id': '669832-1'}},
#   {'score': 0.00168,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea radicalis',
#     'scientificNameAuthorship': 'Mart.',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': [],
#     'scientificName': 'Chamaedorea radicalis Mart.'},
#    'gbif': {'id': '2734396'},
#    'powo': {'id': '54939-2'}},
#   {'score': 0.00152,
#    'species': {'scientificNameWithoutAuthor': 'Trichilia dregeana',
#     'scientificNameAuthorship': 'Sond.',
#     'genus': {'scientificNameWithoutAuthor': 'Trichilia',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Trichilia'},
#     'family': {'scientificNameWithoutAuthor': 'Meliaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Meliaceae'},
#     'commonNames': ['Christmas-bells',
#      'Forest Natal-mahogany',
#      'Forest-mahogany'],
#     'scientificName': 'Trichilia dregeana Sond.'},
#    'gbif': {'id': '3851043'},
#    'powo': {'id': '579408-1'},
#    'iucn': {'id': '146208183', 'category': 'LC'}},
#   {'score': 0.00135,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea pochutlensis',
#     'scientificNameAuthorship': 'Liebm.',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': [],
#     'scientificName': 'Chamaedorea pochutlensis Liebm.'},
#    'gbif': {'id': '2734491'},
#    'powo': {'id': '54931-2'},
#    'iucn': {'id': '44393456', 'category': 'LC'}},
#   {'score': 0.00118,
#    'species': {'scientificNameWithoutAuthor': 'Rhapis excelsa',
#     'scientificNameAuthorship': '(Thunb.) A.Henry',
#     'genus': {'scientificNameWithoutAuthor': 'Rhapis',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Rhapis'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['The Lady Palm'],
#     'scientificName': 'Rhapis excelsa (Thunb.) A.Henry'},
#    'gbif': {'id': '2736747'},
#    'powo': {'id': '669577-1'}},
#   {'score': 0.00118,
#    'species': {'scientificNameWithoutAuthor': 'Viola pedata',
#     'scientificNameAuthorship': 'L.',
#     'genus': {'scientificNameWithoutAuthor': 'Viola',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Viola'},
#     'family': {'scientificNameWithoutAuthor': 'Violaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Violaceae'},
#     'commonNames': ['Bird-foot violet', 'Pansy violet', 'Crowfoot violet'],
#     'scientificName': 'Viola pedata L.'},
#    'gbif': {'id': '5331278'},
#    'powo': {'id': '286957-2'}},
#   {'score': 0.00117,
#    'species': {'scientificNameWithoutAuthor': 'Salacca wallichiana',
#     'scientificNameAuthorship': 'Mart.',
#     'genus': {'scientificNameWithoutAuthor': 'Salacca',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Salacca'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': ['Rakum palm', 'Sala'],
#     'scientificName': 'Salacca wallichiana Mart.'},
#    'gbif': {'id': '2731751'},
#    'powo': {'id': '670334-1'},
#    'iucn': {'id': '111460819', 'category': 'LC'}},
#   {'score': 0.001,
#    'species': {'scientificNameWithoutAuthor': 'Zamia pumila',
#     'scientificNameAuthorship': 'L.',
#     'genus': {'scientificNameWithoutAuthor': 'Zamia',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Zamia'},
#     'family': {'scientificNameWithoutAuthor': 'Zamiaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Zamiaceae'},
#     'commonNames': ['Coontie', 'Florida arrowroot', 'Seminole-bread'],
#     'scientificName': 'Zamia pumila L.'},
#    'gbif': {'id': '5284117'},
#    'powo': {'id': '270561-2'},
#    'iucn': {'id': '42177', 'category': 'VU'}},
#   {'score': 0.001,
#    'species': {'scientificNameWithoutAuthor': 'Chamaedorea costaricana',
#     'scientificNameAuthorship': 'Oerst.',
#     'genus': {'scientificNameWithoutAuthor': 'Chamaedorea',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Chamaedorea'},
#     'family': {'scientificNameWithoutAuthor': 'Arecaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Arecaceae'},
#     'commonNames': [],
#     'scientificName': 'Chamaedorea costaricana Oerst.'},
#    'gbif': {'id': '2734571'},
#    'powo': {'id': '54858-2'}}],
#  'version': '2024-02-22 (7.1)'}
